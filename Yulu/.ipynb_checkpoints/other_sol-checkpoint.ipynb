# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot
import pylab as py

import warnings 
warnings.filterwarnings("ignore")

# %%
# Converting the txt file to csv file

df = pd.read_csv(r'bike_sharing.txt')
df.to_csv (r'bike_sharing.csv', index=None)

# %%
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %% [markdown]
# ## 1. Define Problem Statement and perform Exploratory Data Analysis.

# %% [markdown]
# **1.a. Definition of problem (as per given problem statement with additional views)**\
# => Which variables are significant in predicting the demand for shared electric cycles in the Indian market?\
# => How well those variables describe the electric cycle demands.\
# => To know when do people use our bikes the max and what we should do to increase our business.\
# => Who are our target customers?
# => Which all variables are dependent on each other?
#
# **1.b. Observations on shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required) , missing value detection, statistical summary.**

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# conversion of categorical attributes to 'category' and datetime attribute to 'datetime'

df['season'] = df.season.astype('category')
df['holiday'] = df.holiday.astype('category')
df['workingday'] = df.workingday.astype('category')
df['weather'] = df.weather.astype('category')
df['datetime'] = pd.to_datetime(df['datetime'])   

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  category
#  2   holiday     10886 non-null  category
#  3   workingday  10886 non-null  category
#  4   weather     10886 non-null  category
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: category(4), datetime64[ns](1), float64(3), int64(4)
# memory usage: 723.7 KB

# %%
numerical_cols = ['temp', 'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count']
categorical_cols = ['season', 'holiday', 'workingday', 'weather']

# %%
df[numerical_cols].describe()
# Out:
#               temp         atemp      humidity     windspeed        casual  \
# count  10886.00000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      20.23086     23.655084     61.886460     12.799395     36.021955
# std        7.79159      8.474601     19.245033      8.164537     49.960477
# min        0.82000      0.760000      0.000000      0.000000      0.000000
# 25%       13.94000     16.665000     47.000000      7.001500      4.000000
# 50%       20.50000     24.240000     62.000000     12.998000     17.000000
# 75%       26.24000     31.060000     77.000000     16.997900     49.000000
# max       41.00000     45.455000    100.000000     56.996900    367.000000
#
#          registered         count
# count  10886.000000  10886.000000
# mean     155.552177    191.574132
# std      151.039033    181.144454
# min        0.000000      1.000000
# 25%       36.000000     42.000000
# 50%      118.000000    145.000000
# 75%      222.000000    284.000000
# max      886.000000    977.000000

# %%
df[categorical_cols].describe()
# Out:
#         season  holiday  workingday  weather
# count    10886    10886       10886    10886
# unique       4        2           2        4
# top          4        0           1        1
# freq      2734    10575        7412     7192

# %%
# Count the number of null values in each columns

df.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# Inference: There are no missing values in the dataset.

# %% [markdown]
# Handling Outliers

# %%
df[numerical_cols].boxplot(rot=25, figsize=(25,8))
# Out:
# <AxesSubplot:>

# %%
Q1 = df[numerical_cols].quantile(0.25)
Q3 = df[numerical_cols].quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# temp           12.3000
# atemp          14.3950
# humidity       30.0000
# windspeed       9.9964
# casual         45.0000
# registered    186.0000
# count         242.0000
# dtype: float64

# %%
df = df[~((df[numerical_cols] < (Q1 - 1.5 * IQR)) |(df[numerical_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]
df = df.reset_index(drop=True)

# %%
df
# Out:
#                 datetime season holiday workingday weather   temp   atemp  \
# 0    2011-01-01 00:00:00      1       0          0       1   9.84  14.395
# 1    2011-01-01 01:00:00      1       0          0       1   9.02  13.635
# 2    2011-01-01 02:00:00      1       0          0       1   9.02  13.635
# 3    2011-01-01 03:00:00      1       0          0       1   9.84  14.395
# 4    2011-01-01 04:00:00      1       0          0       1   9.84  14.395
# ...                  ...    ...     ...        ...     ...    ...     ...
# 9513 2012-12-19 19:00:00      4       0          1       1  15.58  19.695
# 9514 2012-12-19 20:00:00      4       0          1       1  14.76  17.425
# 9515 2012-12-19 21:00:00      4       0          1       1  13.94  15.910
# 9516 2012-12-19 22:00:00      4       0          1       1  13.94  17.425
# 9517 2012-12-19 23:00:00      4       0          1       1  13.12  16.665
#
#       humidity  windspeed  casual  registered  count
# 0           81     0.0000       3          13     16
# 1           80     0.0000       8          32     40
# 2           80     0.0000       5          27     32
# 3           75     0.0000       3          10     13
# 4           75     0.0000       0           1      1
# ...        ...        ...     ...         ...    ...
# 9513        50    26.0027       7         329    336
# 9514        57    15.0013      10         231    241
# 9515        61    15.0013       4         164    168
# 9516        61     6.0032      12         117    129
# 9517        66     8.9981       4          84     88
#
# [9518 rows x 12 columns]

# %%
df[numerical_cols].boxplot(rot=25, figsize=(25,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **1.c. Univariate Analysis (distribution plots of all the continuous variable(s) barplots/countplots of all the categorical variables)**

# %%
df
# Out:
#                 datetime season holiday workingday weather   temp   atemp  \
# 0    2011-01-01 00:00:00      1       0          0       1   9.84  14.395
# 1    2011-01-01 01:00:00      1       0          0       1   9.02  13.635
# 2    2011-01-01 02:00:00      1       0          0       1   9.02  13.635
# 3    2011-01-01 03:00:00      1       0          0       1   9.84  14.395
# 4    2011-01-01 04:00:00      1       0          0       1   9.84  14.395
# ...                  ...    ...     ...        ...     ...    ...     ...
# 9513 2012-12-19 19:00:00      4       0          1       1  15.58  19.695
# 9514 2012-12-19 20:00:00      4       0          1       1  14.76  17.425
# 9515 2012-12-19 21:00:00      4       0          1       1  13.94  15.910
# 9516 2012-12-19 22:00:00      4       0          1       1  13.94  17.425
# 9517 2012-12-19 23:00:00      4       0          1       1  13.12  16.665
#
#       humidity  windspeed  casual  registered  count
# 0           81     0.0000       3          13     16
# 1           80     0.0000       8          32     40
# 2           80     0.0000       5          27     32
# 3           75     0.0000       3          10     13
# 4           75     0.0000       0           1      1
# ...        ...        ...     ...         ...    ...
# 9513        50    26.0027       7         329    336
# 9514        57    15.0013      10         231    241
# 9515        61    15.0013       4         164    168
# 9516        61     6.0032      12         117    129
# 9517        66     8.9981       4          84     88
#
# [9518 rows x 12 columns]

# %% [markdown]
# **Numerical columns**

# %%
df["temp"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["temp"], line ='s')
py.show()

# %% [markdown]
# Inference: temp is almost following Normal Distribution

# %%
df["atemp"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["atemp"], line ='s')
py.show()

# %% [markdown]
# Inference: atemp is almost following Normal distribution

# %%
df["humidity"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["humidity"], line ='s')
py.show()

# %% [markdown]
# Inference: humidity is almost following Normal distribution

# %%
df["windspeed"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["windspeed"], line ='s')
py.show()

# %% [markdown]
# Inference: windspeed is almost following Normal distribution

# %%
df["casual"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["casual"], line ='s')
py.show()

# %% [markdown]
# Inference: count of casuals are not following Normal distribution

# %%
df["registered"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["registered"], line ='s')
py.show()

# %% [markdown]
# Inference: count of registered are not following Normal distribution

# %%
df["count"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sm.qqplot(df["count"], line ='s')
py.show()

# %% [markdown]
# Inference: count(both casual and registered) are not following Normal distribution

# %% [markdown]
# **Categorical columns**

# %% [markdown]
# season: season (1: spring, 2: summer, 3: fall, 4: winter)
#
# holiday : weather day is a holiday or not
#
# workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
#
# weather:\
# 1: Clear, Few clouds, partly cloudy, partly cloudy\
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist\
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds\
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
sns.countplot(x="season", data=df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %% [markdown]
# Inference: in all the seasons, number of rides taken used are the same.

# %%
sns.countplot(x="holiday", data=df)
# Out:
# <AxesSubplot:xlabel='holiday', ylabel='count'>

# %% [markdown]
# Inference: number of rides in the non-holidays(weekdays and weekends) are more than holidays(weekends not included).\
# Recommendation: That means during holidays, not much rental bikes are used, so you can use this time to service and maintenace of the bikes.

# %%
sns.countplot(x="workingday", data=df)
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='count'>

# %% [markdown]
# Inference: In weekends also, people use rental bikes but its lesser than that during workingdays.\
# Recommendation: You can leave less bikes during non-working days or more bikes in working hours.

# %%
sns.countplot(x="weather", data=df)
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %% [markdown]
# Inference: During heavy rains(category 4), none of the bikes are used. Most of the bikes are used during category 1 time. And the count reduces as the influence of sun reduces.\
# Recommendation: During category 4, you can introduce few electric cars.

# %% [markdown]
# **1.d. Bivariate Analysis (Relationships between important variables such as workday and count, season and count, weather and count.**

# %%
df
# Out:
#                 datetime season holiday workingday weather   temp   atemp  \
# 0    2011-01-01 00:00:00      1       0          0       1   9.84  14.395
# 1    2011-01-01 01:00:00      1       0          0       1   9.02  13.635
# 2    2011-01-01 02:00:00      1       0          0       1   9.02  13.635
# 3    2011-01-01 03:00:00      1       0          0       1   9.84  14.395
# 4    2011-01-01 04:00:00      1       0          0       1   9.84  14.395
# ...                  ...    ...     ...        ...     ...    ...     ...
# 9513 2012-12-19 19:00:00      4       0          1       1  15.58  19.695
# 9514 2012-12-19 20:00:00      4       0          1       1  14.76  17.425
# 9515 2012-12-19 21:00:00      4       0          1       1  13.94  15.910
# 9516 2012-12-19 22:00:00      4       0          1       1  13.94  17.425
# 9517 2012-12-19 23:00:00      4       0          1       1  13.12  16.665
#
#       humidity  windspeed  casual  registered  count
# 0           81     0.0000       3          13     16
# 1           80     0.0000       8          32     40
# 2           80     0.0000       5          27     32
# 3           75     0.0000       3          10     13
# 4           75     0.0000       0           1      1
# ...        ...        ...     ...         ...    ...
# 9513        50    26.0027       7         329    336
# 9514        57    15.0013      10         231    241
# 9515        61    15.0013       4         164    168
# 9516        61     6.0032      12         117    129
# 9517        66     8.9981       4          84     88
#
# [9518 rows x 12 columns]

# %%
sns.set(rc = {'figure.figsize':(10,10)})
sns.heatmap(df[numerical_cols].corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               temp        atemp     humidity    windspeed       casual  \
# count  9518.000000  9518.000000  9518.000000  9518.000000  9518.000000
# mean     19.589971    22.987399    63.737025    12.133336    23.955033
# std       7.686871     8.361526    18.693175     7.437481    26.956046
# min       0.820000     0.760000     8.000000     0.000000     0.000000
# 25%      13.120000    15.910000    49.000000     7.001500     3.000000
# 50%      18.860000    22.725000    64.500000    11.001400    13.000000
# 75%      26.240000    30.305000    79.000000    16.997900    37.000000
# max      41.000000    45.455000   100.000000    31.000900   116.000000
#
#         registered        count
# count  9518.000000  9518.000000
# mean    126.181025   150.136058
# std     114.116911   131.586548
# min       0.000000     1.000000
# 25%      28.250000    34.000000
# 50%     101.000000   122.000000
# 75%     187.000000   231.000000
# max     501.000000   590.000000

# %% [markdown]
# **workday v/s count**

# %%
df.groupby("workingday")["count"].mean()
# Out:
# workingday
# 0    120.681085
# 1    161.970103
# Name: count, dtype: float64

# %%
df.groupby("workingday")["count"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='workingday'>

# %%
sns.boxplot(data = df, x = "workingday", y = "count")
# Out:
# <AxesSubplot:xlabel='workingday', ylabel='count'>

# %% [markdown]
# Inference: On average, bikes are used workingdays is ~1.5times more than non-workingdays per hour.

# %%
df.groupby("workingday")["count", 'datetime', 'casual', 'registered'].max()
# Out:
#             count            datetime  casual  registered
# workingday
# 0             551 2012-12-16 23:00:00     116         490
# 1             590 2012-12-19 23:00:00     116         501

# %% [markdown]
# Inference: Especially after 9pm, metro & other modes of public transports will stopped, and most of the taxis and autos will be demanding for high amounts, so especially people working at constructions and IT will prefer for electric solo and shared bikes which will reduce the cost of the customer's ride drastically.
#
# Recommendation: In the morning time due to availability of public transport, lot of middle class and one-day wage workers use public transport to reach to their work place. So our main business hours is from 9pm to 12am, we can keep more vehicles in those places where our customers work.

# %% [markdown]
# **season v/s count**

# %%
df.groupby("season")["count"].mean()
# Out:
# season
# 1    103.164028
# 2    160.360820
# 3    177.151661
# 4    162.437172
# Name: count, dtype: float64

# %%
df.groupby("season")["count"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='season'>

# %%
sns.boxplot(data = df, x = "season", y = "count")
# Out:
# <AxesSubplot:xlabel='season', ylabel='count'>

# %%
df.groupby("season")["count", 'datetime', 'casual', 'registered'].max()
# Out:
#         count            datetime  casual  registered
# season
# 1         566 2012-03-19 23:00:00     115         498
# 2         590 2012-06-19 23:00:00     116         500
# 3         587 2012-09-19 23:00:00     116         500
# 4         566 2012-12-19 23:00:00     116         501

# %% [markdown]
# Inference: In all the seasons, the peak hours is between 9pm to 12am.

# %% [markdown]
# **weather v/s count**

# %%
df.groupby("weather")["count"].mean()
# Out:
# weather
# 1    157.522021
# 2    146.805685
# 3    102.170763
# 4    164.000000
# Name: count, dtype: float64

# %%
df.groupby("weather")["count"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='weather'>

# %%
sns.boxplot(data = df, x = "weather", y = "count")
# Out:
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %%
df.groupby("season")["count", 'datetime', 'casual', 'registered'].max()
# Out:
#         count            datetime  casual  registered
# season
# 1         566 2012-03-19 23:00:00     115         498
# 2         590 2012-06-19 23:00:00     116         500
# 3         587 2012-09-19 23:00:00     116         500
# 4         566 2012-12-19 23:00:00     116         501

# %% [markdown]
# Inference: There are few rides per hour during rainy weather but in the peak hours you can see the same number of rides happening as usual. So during rainy weather, we can only keep the bikes during the peak hours.

# %% [markdown]
# ## 2. Hypothesis Testing

# %% [markdown]
# **2.a. 2- Sample T-Test to check if Working Day has an effect on the number of electric cycles rented (10 points)**
#
# ho: count on working day < count on non-working day\
# ha: count on working day >= count on non-working day

# %%
workingday_sample = df["workingday"].sample(n=1000)
count_sample = df["count"].sample(n=1000)

stats.ttest_ind(workingday_sample, count_sample, alternative="less")
# Out:
# Ttest_indResult(statistic=-36.54376351521165, pvalue=1.183422965693989e-224)

# %% [markdown]
# Inference: pvalue<<0.05, we reject our Null hypothesis and accept ha.
#
# Therefore, count on working day >= count on non-working day

# %% [markdown]
# **2.b. ANNOVA to check if No. of cycles rented is similar or different in different 1. weather 2. season (10 points)**

# %% [markdown]
# **2.b.1. weather**
#
# ho: count is same in different weathers \
# h1: count is not same in different weathers

# %%
df.weather.value_counts()
# Out:
# 1    6176
# 2    2568
# 3     773
# 4       1
# Name: weather, dtype: int64

# %%
df.groupby('weather').agg({'count':'sum'}).reset_index(drop=True)
# Out:
#     count
# 0  972856
# 1  376997
# 2   78978
# 3     164

# %%
weather_1 = df[df["weather"]==1]["count"].sample(n=500)
weather_2 = df[df["weather"]==2]["count"].sample(n=500)
weather_3 = df[df["weather"]==3]["count"].sample(n=500)

weather_1 = weather_1.reset_index(drop=True)
weather_2 = weather_2.reset_index(drop=True)
weather_3 = weather_3.reset_index(drop=True)

dataset = pd.DataFrame({"1":weather_1, "2":weather_2, "3":weather_3})
dataset
# Out:
#        1    2    3
# 0    308  112  312
# 1      1  339   20
# 2    103  106  194
# 3     69   52  132
# 4    138  180   19
# ..   ...  ...  ...
# 495   99  418    1
# 496   70  237    2
# 497   29  258   71
# 498   67  382  407
# 499  334  497   96
#
# [500 rows x 3 columns]

# %%
f, pval = stats.f_oneway(dataset["1"], dataset["2"], dataset["3"])
print(f, pval)
# Out:
# 32.08987980588854 2.2595026108213704e-14

# %% [markdown]
# Inference: Since pvalue<0.05, we reject ho and go with ha.

# %%
mean_1 = dataset['1'].mean()
mean_2 = dataset['2'].mean()
mean_3 = dataset['3'].mean()

print(mean_1, mean_2, mean_3)
# Out:
# 160.26 139.146 99.026

# %%
sns.distplot(dataset['1'], bins = 10)
# Out:
# <AxesSubplot:xlabel='1', ylabel='Density'>

# %%
sm.qqplot(dataset['1'], line = "s")
py.show()

# %% [markdown]
# Inference: weather_1 is not following Normal distribution.

# %% [markdown]
# Lets try to do Bootstrapping and see if Sampling distribution follow Normal distribution or not. Irrespective of how your distribution is, if your smapling distribution follows a Normal distribution, we can approximate from CLT.

# %%
weather_1_samp = []
for i in range(500):
    w1 = df[df["weather"]==1]["count"].sample(n=200)
    av = w1.mean()
    weather_1_samp.append(av)

# %%
sns.distplot(weather_1_samp, bins = 20)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Inference: This is following Normal Distribution.

# %%
np.mean(weather_1_samp)
# Out:
# 158.044

# %%
mu = (mean_1*500 + mean_2*500 + mean_3*500)/1500
mu
# Out:
# 132.81066666666666

# %%
ssw = sum((weather_1-mean_1)**2 + (weather_2-mean_2)**2 + (weather_3-mean_3)**2)
ssw
# Out:
# 22567115.20399998

# %%
ssg = ((mean_1 - mu)**2)*500 + ((mean_2 - mu)**2)*500 + ((mean_3 - mu)**2)*500
ssg
# Out:
# 967503.0253333332

# %%
msg = ssg/2
msg
# Out:
# 483751.5126666666

# %%
msw = ssw/(1500-3)
msw
# Out:
# 15074.89325584501

# %%
fstat = msg/msw
fstat
# Out:
# 32.08987980588857

# %% [markdown]
# Then to get Fcritical values look at the F-distribution table.
#
# ![ftable.gif](attachment:ftable.gif)
#
# fcrit~=3.0
#
# Since fcrit<<45.198, we reject ho and accept ha.

# %% [markdown]
# **2.b.2. season**
#
# ho: count is not same in different seasons\
# h1: count is same in different seasons

# %%
df.season.value_counts()
# Out:
# 4    2475
# 1    2463
# 2    2292
# 3    2288
# Name: season, dtype: int64

# %%
df.groupby('season').agg({'count':'sum'}).reset_index(drop=True)
# Out:
#     count
# 0  254093
# 1  367547
# 2  405323
# 3  402032

# %%
season_1 = df[df["season"]==1]["count"].sample(n=500)
season_2 = df[df["season"]==2]["count"].sample(n=500)
season_3 = df[df["season"]==3]["count"].sample(n=500)
season_4 = df[df["season"]==3]["count"].sample(n=500)

season_1 = season_1.reset_index(drop=True)
season_2 = season_2.reset_index(drop=True)
season_3 = season_3.reset_index(drop=True)
season_4 = season_4.reset_index(drop=True)

dataset = pd.DataFrame({"1":season_1, "2":season_2, "3":season_3, "4":season_4})
dataset
# Out:
#        1    2    3    4
# 0     83   92  236  223
# 1     78   13  441  343
# 2     71    5  284    7
# 3     40  486  129  268
# 4     82  388  152   14
# ..   ...  ...  ...  ...
# 495   17   59  140  207
# 496  161   52   22    7
# 497   57  135    7  161
# 498   18  286  266  176
# 499  202  274  318   52
#
# [500 rows x 4 columns]

# %%
f, pval = stats.f_oneway(dataset["1"], dataset["2"], dataset["3"], dataset["4"])
print(f, pval)
# Out:
# 38.25960961101622 4.8977501313665634e-24

# %% [markdown]
# Inference: pvalue<0.05, that means we reject ho and accept ha

# %%
mean_1 = dataset['1'].mean()
mean_2 = dataset['2'].mean()
mean_3 = dataset['3'].mean()
mean_4 = dataset['4'].mean()

print(mean_1, mean_2, mean_3, mean_4)
# Out:
# 101.176 161.15 180.278 173.446

# %%
sns.distplot(dataset['1'], bins = 10)
# Out:
# <AxesSubplot:xlabel='1', ylabel='Density'>

# %%
sm.qqplot(dataset['1'], line = "s")
py.show()

# %% [markdown]
# Inference: season_1 is not following Normal distribution.
#
# Lets try to do Bootstrapping and see if Sampling distribution follow Normal distribution or not. Irrespective of how your distribution is, if your smapling distribution follows a Normal distribution, we can approximate from CLT.

# %%
season_1_samp = []
for i in range(500):
    s1 = df[df["season"]==1]["count"].sample(n=200)
    av = s1.mean()
    season_1_samp.append(av)

# %%
sns.distplot(weather_1_samp, bins = 20)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Inference: This is following Normal distribution

# %%
np.mean(weather_1_samp)
# Out:
# 158.044

# %%
mu = (mean_1*500 + mean_2*500 + mean_3*500 + mean_4*500)/2000
mu
# Out:
# 154.0125

# %%
ssw = sum((season_1-mean_1)**2 + (season_2-mean_2)**2 + (season_3-mean_3)**2 + (season_4-mean_4)**2)
ssw
# Out:
# 33998924.162000015

# %%
ssg = ((mean_1 - mu)**2)*500 + ((mean_2 - mu)**2)*500 + ((mean_3 - mu)**2)*500 + ((mean_4 - mu)**2)*500
ssg
# Out:
# 1955088.5254999998

# %%
msg = ssg/3
msg
# Out:
# 651696.1751666666

# %%
msw = ssw/(2000-4)
msw
# Out:
# 17033.529139278566

# %%
fstat = msg/msw
fstat
# Out:
# 38.259609611016195

# %% [markdown]
# Then to get Fcritical values look at the F-distribution table.
#
# ![ftable.gif](attachment:ftable.gif)
#
# fcrit~=2.609
#
# Since fcrit<<33.58, we reject ho and accept ha.

# %% [markdown]
# Inference:
# 1. count is different in different weather.
# 2. count is same in different seasons.

# %% [markdown]
# **2.c. Chi-square test to check if Weather is dependent on the season (10 points)**
#
# Hypothesis Testing:\
# ho: There is no relationship btw weather and season.\
# ha: There is relationship btw weather and season.

# %%
ctab = pd.crosstab(df['weather'], df['season'])
ctab
# Out:
# season      1     2     3     4
# weather
# 1        1595  1473  1598  1510
# 2         683   614   517   754
# 3         184   205   173   211
# 4           1     0     0     0

# %%
from scipy.stats import chi2_contingency

# %%
stat, p, dof, expected = chi2_contingency(ctab)

# %%
print("Chi-square stat:",stat)
print("pvalue :",p)
# Out:
# Chi-square stat: 49.956607077688595
# pvalue : 1.0976664201931212e-07

# %% [markdown]
# dof = (r-1)*(c-1) = 9
#
# alpha = 0.05
#
# chi-stats = 49.95
#
# See the Chi-square distribution table to know the chi-crit.\
# chi-crit = 16.919
#
# chi-crit < chi-stats, so we reject ho and accepts ha.
#
# Therefore, there is relationship btw weather and season ie weather and season are dependent on each other.

# %%
sns.histplot(binwidth=0.5, x="weather", hue="season", data=df, stat="count", multiple="stack")
# Out:
# <AxesSubplot:xlabel='weather', ylabel='Count'>

# %% [markdown]
# Insights and Recommendations:
# 1. In all the seasons, count of rental biked used are the same.
# 2. During holidays, not much rental bikes are used, so you can use this time to service and maintenance of the bikes.
# 3. You can leave less bikes during non-working days.
# 4. During heavy rains(category 4), none of the bikes are used. Most of the bikes are used during category 1 time. And the count reduces as the influence of sun reduces. During category 4, you can introduce few electric cars.
# 5. So, I would recommend to also keep some electric cars also for rent to make some business during weather of category 3 and 4. During this time, you will have least demand of the service.
# 6. Especially after 9pm, metro & other modes of public transports will stopped, and most of the taxis and autos will be demanding for high amounts, so especially people working at constructions and IT will prefer for electric solo and shared bikes which will reduce the cost of the customer's ride drastically. In the morning time due to availability of public transport, lot of middle class and one-day wage workers use public transport to reach to their work place. So our main business hours is from 9pm to 12am, we can keep more vehicles in those places where our customers work.
# 7. In all the seasons, the peak hours is between 9pm to 12am.
# 8. There are few rides per hour during rainy weather but in the peak hours you can see the same number of rides happening as usual. So during rainy weather, we can only keep the bikes during the peak hours.
# 9.  No. of cycles rented is similar in different seasons but different in different weathers.
#
# Please find the link of the google drive of pdf and ipython notebook:
# https://drive.google.com/drive/folders/1CvMbOBRdgnNOwIy9KNWksdRWgd2EdVxl?usp=sharing
